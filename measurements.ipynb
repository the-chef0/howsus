# %%
{
    'numpy': {
        'abstractness': 0.001141552511415525,
        'instability': 0.6371235090577538,
        'merged_prs': 123,
        'closed_issues': 47,
        'low_vulns': 4,
        'medium_vulns': 2,
        'high_vulns': 1,
        'crit_vulns': 0
    },
    'pandas': {
        'abstractness': 0.00924321201617562,
        'instability': 0.6310823667273677,
        'merged_prs': 70,
        'closed_issues': 66,
        'low_vulns': 0,
        'medium_vulns': 0,
        'high_vulns': 1,
        'crit_vulns': 0
    },
    'scikit-learn': {
        'abstractness': 0.009313154831199068,
        'instability': 0.6714812553303767,
        'merged_prs': 76,
        'closed_issues': 29,
        'low_vulns': 1,
        'medium_vulns': 2,
        'high_vulns': 0,
        'crit_vulns': 0
    },
    'tensorflow': {
        'abstractness': 0.001139508383525964,
        'instability': 0.6167651670668122,
        'merged_prs': 1000,
        'closed_issues': 82,
        'low_vulns': 121,
        'medium_vulns': 188,
        'high_vulns': 132,
        'crit_vulns': 8
    },
    'pytorch': {
        'abstractness': 0.016240266963292546,
        'instability': 0.5351253989596315,
        'merged_prs': 16,
        'closed_issues': 549,
        'low_vulns': 0,
        'medium_vulns': 2,
        'high_vulns': 2,
        'crit_vulns': 1
    },
    'lightgbm': {
        'abstractness': 0.021739130434782608,
        'instability': 0.4192307692307692,
        'merged_prs': 3,
        'closed_issues': 8,
        'low_vulns': 0,
        'medium_vulns': 0,
        'high_vulns': 0,
        'crit_vulns': 1
    },
    'cuml': {
        'abstractness': 0,
        'instability': 0.5849633026593889,
        'merged_prs': 82,
        'closed_issues': 26,
        'low_vulns': 0,
        'medium_vulns': 0,
        'high_vulns': 0,
        'crit_vulns': 0
    },
    'requests': {
        'abstractness': 0,
        'instability': 0.36205281178988147,
        'merged_prs': 0,
        'closed_issues': 9,
        'low_vulns': 0,
        'medium_vulns': 7,
        'high_vulns': 1,
        'crit_vulns': 1
    },
    'urllib3': {
        'abstractness': 0,
        'instability': 0.3977419958384964,
        'merged_prs': 6,
        'closed_issues': 3,
        'low_vulns': 1,
        'medium_vulns': 8,
        'high_vulns': 4,
        'crit_vulns': 0
    },
    'aiohttp': {
        'abstractness': 0.05673758865248227,
        'instability': 0.4610315434082998,
        'merged_prs': 110,
        'closed_issues': 7,
        'low_vulns': 0,
        'medium_vulns': 15,
        'high_vulns': 3,
        'crit_vulns': 0
    },
    'httpx': {
        'abstractness': 0,
        'instability': 0.3982413180689042,
        'merged_prs': 3,
        'closed_issues': 2,
        'low_vulns': 0,
        'medium_vulns': 2,
        'high_vulns': 0,
        'crit_vulns': 0
    },
    'regex': {
        'abstractness': 0,
        'instability': 0,
        'merged_prs': 0,
        'closed_issues': 0,
        'low_vulns': 0,
        'medium_vulns': 0,
        'high_vulns': 1,
        'crit_vulns': 0
    },
    'pyparsing': {
        'abstractness': 0.00909090909090909,
        'instability': 0.40187074829931974,
        'merged_prs': 0,
        'closed_issues': 0,
        'low_vulns': 0,
        'medium_vulns': 0,
        'high_vulns': 0,
        'crit_vulns': 0
    },
    'nltk': {
        'abstractness': 0.0011695906432748538,
        'instability': 0.6435253527757231,
        'merged_prs': 5,
        'closed_issues': 9,
        'low_vulns': 0,
        'medium_vulns': 5,
        'high_vulns': 3,
        'crit_vulns': 0
    },
    'spacy': {
        'abstractness': 0,
        'instability': 0.31887078080275805,
        'merged_prs': 0,
        'closed_issues': 2,
        'low_vulns': 0,
        'medium_vulns': 0,
        'high_vulns': 0,
        'crit_vulns': 0
    },
    'sympy': {
        'abstractness': 0.006602112676056338,
        'instability': 0.6560753102347185,
        'merged_prs': 48,
        'closed_issues': 50,
        'low_vulns': 0,
        'medium_vulns': 0,
        'high_vulns': 1,
        'crit_vulns': 0
    },
    'scipy': {
        'abstractness': 0.002789400278940028,
        'instability': 0.6847484598580642,
        'merged_prs': 82,
        'closed_issues': 58,
        'low_vulns': 0,
        'medium_vulns': 1,
        'high_vulns': 2,
        'crit_vulns': 0
    },
    'pyarrow': {
        'abstractness': 0.01020408163265306,
        'instability': 0.5097882596875615,
        'merged_prs': 93,
        'closed_issues': 87,
        'low_vulns': 0,
        'medium_vulns': 2,
        'high_vulns': 0,
        'crit_vulns':1
    },
}
# Out:
# {'numpy': {'abstractness': 0.001141552511415525,
#   'instability': 0.6371235090577538,
#   'merged_prs': 123,
#   'closed_issues': 47,
#   'low_vulns': 4,
#   'medium_vulns': 2,
#   'high_vulns': 1,
#   'crit_vulns': 0},
#  'pandas': {'abstractness': 0.00924321201617562,
#   'instability': 0.6310823667273677,
#   'merged_prs': 70,
#   'closed_issues': 66,
#   'low_vulns': 0,
#   'medium_vulns': 0,
#   'high_vulns': 1,
#   'crit_vulns': 0},
#  'scikit-learn': {'abstractness': 0.009313154831199068,
#   'instability': 0.6714812553303767,
#   'merged_prs': 76,
#   'closed_issues': 29,
#   'low_vulns': 1,
#   'medium_vulns': 2,
#   'high_vulns': 0,
#   'crit_vulns': 0},
#  'tensorflow': {'abstractness': 0.001139508383525964,
#   'instability': 0.6167651670668122,
#   'merged_prs': 1000,
#   'closed_issues': 82,
#   'low_vulns': 121,
#   'medium_vulns': 188,
#   'high_vulns': 132,
#   'crit_vulns': 8},
#  'pytorch': {'abstractness': 0.016240266963292546,
# ...
